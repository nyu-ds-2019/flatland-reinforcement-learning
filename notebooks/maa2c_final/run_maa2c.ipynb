# %%
! python3 run_maa2c.py
# Out:
# {'n_agents': 2, 'x_dim': 25, 'y_dim': 25, 'n_cities': 4, 'max_rails_between_cities': 3, 'max_rails_in_city': 4, 'observation_tree_depth': 3, 'observation_radius': 30, 'seed': -1, 'rail_generator': 'sparse', 'stack_obs': False, 'how_many_stack': 2, 'regenerate_env': False, 'regenerate_env_step': 50, 'use_predictor': True, 'policy': 'ppo'}
# Env generation seed: 88, agents: 2, rows: 25, cols: 25
# /ext3/miniconda3/lib/python3.8/site-packages/flatland/envs/rail_generators.py:780: UserWarning: Could not set all required cities!
#   warnings.warn(
# Env generation seed: 47, agents: 2, rows: 25, cols: 25
# /ext3/miniconda3/lib/python3.8/site-packages/flatland/envs/rail_generators.py:703: UserWarning: [WARNING] Changing to Grid mode to place at least 2 cities.
#   warnings.warn("[WARNING] Changing to Grid mode to place at least 2 cities.")
# /home/prs392/codes/drl/Project/maa2c_final/common/Model.py:8: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# ...
